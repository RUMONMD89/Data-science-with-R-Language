# %% [markdown]
# <a href="https://colab.research.google.com/github/RUMONMD89/Data-science-with-R-Language/blob/main/ADS9_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Chapter 9
fram_train <- read.csv("Framingham_Training.csv")
fram_train$Death <- as.factor(fram_train$Death)
fram_train$Sex <- as.factor(fram_train$Sex)

fram_train$Age.mm <- (fram_train$Age -  min(fram_train$Age)) / (max(fram_train$Age) -   min(fram_train$Age))

#install.packages("nnet")
install.packages("NeuralNetTools")
library(nnet)
library(NeuralNetTools)

nnet01 <- nnet(Death ~ Sex + Age.mm, data = fram_train,  size = 1)

plotnet(nnet01)

print("W_B1H, W_I1H1, W_I2H1, W_B2O1, W_H1O1 = ")
nnet01$wts
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘Rcpp’, ‘reshape2’
# # weights:  5
# initial  value 7508.253439
# iter  10 value 4694.179722
# iter  20 value 4408.476479
# iter  30 value 4396.554973
# iter  40 value 4395.048136
# iter  50 value 4394.927792
# iter  50 value 4394.927778
# final  value 4394.927778
# converged
# [1] "W_B1H, W_I1H1, W_I2H1, W_B2O1, W_H1O1 = "
# [1] -1.9158841 -0.6348499  3.0461324 -2.7777678  5.9169799
# plot without title
