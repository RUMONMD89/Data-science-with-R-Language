# %% [markdown]
# <a href="https://colab.research.google.com/github/RUMONMD89/Data-science-with-R-Language/blob/main/ADS2REV_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Chapter 2
#install.packages("ggplot2")
library(ggplot2)

bank_train <- read.csv("bank_marketing_training.csv")

table(bank_train$response, bank_train$previous_outcome)

t1 <- table(bank_train$response, bank_train$previous_outcome)

t1
# Out:
#
#       failure nonexistent success
#   no     2390       21176     320
#   yes     385        2034     569
#
#       failure nonexistent success
#   no     2390       21176     320
#   yes     385        2034     569

# %%
  bank_train[1, ]
# Out:
#   age job       marital education default housing loan contact   month
# 1 56  housemaid married basic.4y  no      no      no   telephone may
#   day_of_week ⋯ campaign days_since_previous previous previous_outcome
# 1 mon         ⋯ 1        999                 0        nonexistent
#   emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed response
# 1 1.1          93.994         -36.4         4.857     5191        no

# %%
bank_train[c(1, 3, 4), ]
# Out:
#   age job         marital education   default housing loan contact   month
# 1 56  housemaid   married basic.4y    no      no      no   telephone may
# 3 41  blue-collar married unknown     unknown no      no   telephone may
# 4 25  services    single  high.school no      yes     no   telephone may
#   day_of_week ⋯ campaign days_since_previous previous previous_outcome
# 1 mon         ⋯ 1        999                 0        nonexistent
# 3 mon         ⋯ 1        999                 0        nonexistent
# 4 mon         ⋯ 1        999                 0        nonexistent
#   emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed response
# 1 1.1          93.994         -36.4         4.857     5191        no
# 3 1.1          93.994         -36.4         4.857     5191        no
# 4 1.1          93.994         -36.4         4.857     5191        no

# %%
bank_train[, c(1, 3)]
# Out:
#       age marital
# 1     56  married
# 2     57  married
# 3     41  married
# 4     25  single
# 5     29  single
# 6     57  divorced
# 7     35  married
# 8     39  single
# 9     30  married
# 10    55  single
# 11    41  single
# 12    37  married
# 13    35  married
# 14    46  married
# 15    49  married
# 16    54  divorced
# 17    55  married
# 18    34  married
# 19    52  married
# 20    41  married
# 21    58  unknown
# 22    32  married
# 23    38  single
# 24    44  married
# 25    40  married
# 26    35  married
# 27    54  married
# 28    53  single
# 29    55  married
# 30    25  single
# ⋮     ⋮   ⋮
# 26845 31  married
# 26846 33  married
# 26847 37  married
# 26848 43  divorced
# 26849 29  single
# 26850 26  single
# 26851 41  married
# 26852 35  single
# 26853 41  married
# 26854 26  single
# 26855 41  married
# 26856 41  married
# 26857 31  single
# 26858 33  married
# 26859 35  divorced
# 26860 38  divorced
# 26861 32  married
# 26862 32  married
# ...

# %%
bank_train$age
# Out:
#     [1] 56 57 41 25 29 57 35 39 30 55 41 37 35 46 49 54 55 34 52 41 58 32 38 44
#    [25] 40 35 54 53 55 25 47 42 42 48 37 44 33 56 44 41 44 47 41 55 33 55 50 51
#    [49] 49 38 31 49 34 35 33 42 45 53 44 49 54 52 52 43 35 42 60 58 35 37 36 52
#    [73] 57 56 40 49 45 32 50 56 37 41 52 39 34 53 42 35 60 56 40 36 51 43 59 37
#    [97] 40 42 39 38 40 54 43 45 42 46 44 51 28 37 34 46 36 57 51 34 38 42 34 48
#   [121] 40 43 33 39 43 44 35 35 35 35 36 57 39 30 40 43 46 40 58 35 39 50 32 39
#   [145] 52 44 56 33 30 33 36 36 33 40 41 28 53 58 45 43 33 27 42 27 34 31 54 52
#   [169] 47 49 55 56 53 42 44 39 60 36 42 31 53 45 49 35 38 38 59 43 42 40 46 57
#   [193] 42 27 36 40 34 56 42 43 54 54 40 26 36 29 36 50 49 42 36 41 57 32 58 52
#   [217] 50 33 57 53 43 36 58 40 45 46 36 41 49 37 43 49 41 38 33 33 30 59 48 44
#   [241] 59 50 42 45 36 41 42 52 39 42 41 55 30 45 51 39 34 57 49 38 49 58 43 50
#   [265] 31 43 43 30 27 51 35 47 46 40 26 32 45 42 57 48 54 40 44 42 39 42 43 31
# ...

# %%
hist(bank_train$age)
# Out:
# Plot with title “Histogram of bank_train$age”
